# %%
import pandas as pd

# %%
df = pd.read_csv('BalanceofTrade.csv')

# %%
df.head(20)
# Out:
#                   External Sector selected indicators Unnamed: 1 Unnamed: 2  \
# 0   Current Account, Goods and Services, Net, US D...        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2    Source: International Financial Statistics (IFS)        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                             Country      Scale  Base Year
# 5                        Afghanistan, Islamic Rep. of   Millions        NaN
# 6                                             Albania   Millions        NaN
# 7                                             Algeria   Millions        NaN
# 8                            Andorra, Principality of   Millions        NaN
# 9                                              Angola   Millions        NaN
# 10                                           Anguilla   Millions        NaN
# ...
