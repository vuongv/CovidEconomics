# %%
import pandas as pd

# %%
GDP_growthrate_df = pd.read_csv('ECONGROWTH_2020.csv')
GDP_growthrate_df.head(20)
# Out:
#                 Country Code  Year  Economic growth
# 0           Afghanistan  AFG  2020            -2.35
# 1               Albania  ALB  2020            -3.48
# 2               Algeria  DZA  2020            -5.10
# 3               Andorra  AND  2020           -11.18
# 4                Angola  AGO  2020            -5.60
# 5   Antigua and Barbuda  ATG  2020           -20.19
# 6             Argentina  ARG  2020            -9.94
# 7               Armenia  ARM  2020            -7.20
# 8                 Aruba  ABW  2020           -18.59
# 9             Australia  AUS  2020            -0.05
# 10              Austria  AUT  2020            -6.45
# 11           Azerbaijan  AZE  2020            -4.30
# 12              Bahamas  BHS  2020           -23.82
# 13              Bahrain  BHR  2020            -4.94
# 14           Bangladesh  BGD  2020             3.45
# 15             Barbados  BRB  2020           -13.31
# 16              Belarus  BLR  2020            -0.70
# ...

# %%
top_gdp_df = GDP_growthrate_df.sort_values(by='Economic growth', ascending=False).head(15)

# Sort the dataframe by GDP_change_pct in ascending order and select top 15 rows
bottom_gdp_df = GDP_growthrate_df.sort_values(by='Economic growth', ascending=True).head(15)

top_gdp_df
# Out:
#                    Country Code  Year  Economic growth
# 69                  Guyana  GUY  2020            43.48
# 79                 Ireland  IRL  2020             6.18
# 55                Ethiopia  ETH  2020             6.06
# 67                  Guinea  GIN  2020             4.92
# 167             Tajikistan  TJK  2020             4.40
# 19                   Benin  BEN  2020             3.85
# 51                   Egypt  EGY  2020             3.57
# 121                  Niger  NER  2020             3.55
# 14              Bangladesh  BGD  2020             3.45
# 77                    Iran  IRN  2020             3.33
# 29         Burma (Myanmar)  MMR  2020             3.17
# 146  Sao Tome and Principe  STP  2020             3.02
# 176                 Uganda  UGA  2020             2.95
# 184                Vietnam  VNM  2020             2.87
# 156                Somalia  SOM  2020             2.49

# %%
bottom_gdp_df
# Out:
#                  Country Code  Year  Economic growth
# 99                 Macao  MAC  2020           -54.24
# 103             Maldives  MDV  2020           -33.49
# 142          Saint Lucia  LCA  2020           -24.36
# 96                 Libya  LBY  2020           -23.93
# 12               Bahamas  BHS  2020           -23.82
# 93               Lebanon  LBN  2020           -21.40
# 5    Antigua and Barbuda  ATG  2020           -20.19
# 8                  Aruba  ABW  2020           -18.59
# 129               Panama  PAN  2020           -17.94
# 56                  Fiji  FJI  2020           -17.00
# 48              Dominica  DMA  2020           -16.60
# 162             Suriname  SUR  2020           -15.98
# 113           Montenegro  MNE  2020           -15.31
# 34            Cape Verde  CPV  2020           -14.78
# 107            Mauritius  MUS  2020           -14.60

# %%
GDP_growthrate_2021_df = pd.read_csv('ECONGROWTH_2021.csv')
GDP_growthrate_2021_df.head(20)
# Out:
#                 Country Code  Year  Econ growth 2021
# 0           Afghanistan  AFG  2021            -20.74
# 1               Albania  ALB  2021              8.52
# 2               Algeria  DZA  2021              3.50
# 3               Andorra  AND  2021              8.95
# 4                Angola  AGO  2021              1.10
# 5   Antigua and Barbuda  ATG  2021              5.27
# 6             Argentina  ARG  2021             10.40
# 7               Armenia  ARM  2021              5.70
# 8                 Aruba  ABW  2021             17.17
# 9             Australia  AUS  2021              2.24
# 10              Austria  AUT  2021              4.56
# 11           Azerbaijan  AZE  2021              5.60
# 12              Bahamas  BHS  2021             13.72
# 13              Bahrain  BHR  2021              2.23
# 14           Bangladesh  BGD  2021              6.94
# 15             Barbados  BRB  2021             -0.19
# 16              Belarus  BLR  2021              2.30
# ...

# %%
top_gdp_2021_df = GDP_growthrate_df.sort_values(by='Econ growth 2021', ascending=False).head(15)

# Sort the dataframe by GDP_change_pct in ascending order and select top 15 rows
bottom_gdp__2021_df = GDP_growthrate_df.sort_values(by='Econ growth 2021', ascending=True).head(15)

top_gdp_2021_df
# Out:
#         Country Code  Year  Econ growth 2021
# 102    Maldives  MDV  2021             41.75
# 95        Libya  LBY  2021             31.37
# 110      Monaco  MCO  2021             21.55
# 69       Guyana  GUY  2021             20.06
# 98        Macao  MAC  2021             19.27
# 8         Aruba  ABW  2021             17.17
# 128      Panama  PAN  2021             15.34
# 18       Belize  BLZ  2021             15.23
# 109     Moldova  MDA  2021             13.94
# 12      Bahamas  BHS  2021             13.72
# 79      Ireland  IRL  2021             13.59
# 131        Peru  PER  2021             13.35
# 42      Croatia  HRV  2021             13.07
# 71     Honduras  HND  2021             12.53
# 112  Montenegro  MNE  2021             12.43

# %%
bottom_gdp__2021_df
# Out:
#                    Country Code  Year  Econ growth 2021
# 0              Afghanistan  AFG  2021            -20.74
# 29         Burma (Myanmar)  MMR  2021            -17.91
# 126                  Palau  PLW  2021            -13.33
# 143                  Samoa  WSM  2021             -7.08
# 92                 Lebanon  LBN  2021             -7.00
# 56                    Fiji  FJI  2021             -5.11
# 108             Micronesia  FSM  2021             -3.19
# 160               Suriname  SUR  2021             -2.73
# 168                  Tonga  TON  2021             -2.67
# 137  Republic of the Congo  COG  2021             -2.20
# 159                  Sudan  SDN  2021             -1.87
# 70                   Haiti  HTI  2021             -1.80
# 26                  Brunei  BRN  2021             -1.59
# 36                    Chad  TCD  2021             -1.20
# 169    Trinidad and Tobago  TTO  2021             -1.03

# %%
GDP_growthrate_both_df = pd.read_csv('ECONGROWTH_2020_2021.csv')
GDP_growthrate_both_df.head(20)
# Out:
#                 Country Code  Econ growth 2020  Econ growth 2021
# 0           Afghanistan  AFG             -2.35            -20.74  \
# 1               Albania  ALB             -3.48              8.52
# 2               Algeria  DZA             -5.10              3.50
# 3               Andorra  AND            -11.18              8.95
# 4                Angola  AGO             -5.60              1.10
# 5   Antigua and Barbuda  ATG            -20.19              5.27
# 6             Argentina  ARG             -9.94             10.40
# 7               Armenia  ARM             -7.20              5.70
# 8                 Aruba  ABW            -18.59             17.17
# 9             Australia  AUS             -0.05              2.24
# 10              Austria  AUT             -6.45              4.56
# 11           Azerbaijan  AZE             -4.30              5.60
# 12              Bahamas  BHS            -23.82             13.72
# ...

# %%
top_gdp_avg_df = GDP_growthrate_both_df.sort_values(by='Avg Econ Growth', ascending=False).head(15)

# Sort the dataframe by GDP_change_pct in ascending order and select top 15 rows
bottom_gdp__avg_df = GDP_growthrate_both_df.sort_values(by='Avg Econ Growth', ascending=True).head(15)

top_gdp_avg_df
# Out:
#           Country Code  Econ growth 2020  Econ growth 2021  Avg Econ Growth
# 69         Guyana  GUY             43.48             20.06           31.770
# 79        Ireland  IRL              6.18             13.59            9.885
# 164    Tajikistan  TJK              4.40              9.20            6.800
# 171        Turkey  TUR              1.94             11.35            6.645
# 55       Ethiopia  ETH              6.06              5.64            5.850
# 19          Benin  BEN              3.85              7.16            5.505
# 14     Bangladesh  BGD              3.45              6.94            5.195
# 38          China  CHN              2.24              8.11            5.175
# 179    Uzbekistan  UZB              1.89              7.42            4.655
# 82    Ivory Coast  CIV              1.98              7.04            4.510
# 28   Burkina Faso  BFA              1.93              6.91            4.420
# ...

# %%
bottom_gdp__avg_df
# Out:
#                  Country Code  Econ growth 2020  Econ growth 2021
# 98                 Macao  MAC            -54.24             19.27  \
# 92               Lebanon  LBN            -21.40             -7.00
# 0            Afghanistan  AFG             -2.35            -20.74
# 126                Palau  PLW             -9.11            -13.33
# 56                  Fiji  FJI            -17.00             -5.11
# 160             Suriname  SUR            -15.98             -2.73
# 5    Antigua and Barbuda  ATG            -20.19              5.27
# 29       Burma (Myanmar)  MMR              3.17            -17.91
# 15              Barbados  BRB            -13.31             -0.19
# 141          Saint Lucia  LCA            -24.36             12.23
# 106            Mauritius  MUS            -14.60              3.70
# 143                Samoa  WSM             -3.11             -7.08
# 12               Bahamas  BHS            -23.82             13.72
# ...

# %%
critical_indicators_df = pd.read_csv('Five_critical_indicators.csv')
critical_indicators_df.head(20)
# Out:
#                 Country Code  Year  Exports as percent of GDP
# 0           Afghanistan  AFG  2019                        NaN  \
# 1               Albania  ALB  2019                      31.30
# 2               Algeria  DZA  2019                      22.71
# 3               Andorra  AND  2019                        NaN
# 4                Angola  AGO  2019                      40.79
# 5   Antigua and Barbuda  ATG  2019                      70.88
# 6             Argentina  ARG  2019                      17.92
# 7               Armenia  ARM  2019                      41.35
# 8                 Aruba  ABW  2019                      73.02
# 9             Australia  AUS  2019                      24.15
# 10              Austria  AUT  2019                      55.76
# 11           Azerbaijan  AZE  2019                      49.05
# 12              Bahamas  BHS  2019                      35.69
# 13              Bahrain  BHR  2019                      76.49
# ...
