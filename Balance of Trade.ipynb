# %%
import pandas as pd
import requests
import pprint
import pycountry
import json
fred_api_key = 'c98f06b9ff696165b5171fbfe500692f'

# %%
fred_api_key = 'c98f06b9ff696165b5171fbfe500692f'

# create an empty list to store the country names
country_names = []

# iterate over all the countries and append their names to the list
for country in pycountry.countries:
    country_names.append(country.name)

# loop through each country and get the series code
usable_countries = []  # create a new list to store countries with available CPI data
for country in country_names:
    # format the search query for FRED
    query = f"Balance of Trade for {country}"
    url = f"https://api.stlouisfed.org/fred/series/search?search_text={query}&api_key={fred_api_key}&file_type=json"
    # make a request to FRED API with the search query
    response = requests.get(url).json()
    # extract the series ID if the search returned results
    # check if there are any series codes returned
    if len(response['seriess']) > 0:
        series = response['seriess'][0]
        id = series['id']
        usable_countries.append([country,id])
        print(f'Got series code for {country}')
    else:
        print(f'No series code for {country}')
# Out:
# No series code for Aruba
# No series code for Afghanistan
# Got series code for Angola
# No series code for Anguilla
# No series code for Åland Islands
# Got series code for Albania
# No series code for Andorra
# No series code for United Arab Emirates
# Got series code for Argentina
# Got series code for Armenia
# No series code for American Samoa
# No series code for Antarctica
# No series code for French Southern Territories
# Got series code for Antigua and Barbuda
# Got series code for Australia
# Got series code for Austria
# Got series code for Azerbaijan
# Got series code for Burundi
# Got series code for Belgium
# Got series code for Benin
# No series code for Bonaire, Sint Eustatius and Saba
# Got series code for Burkina Faso
# Got series code for Bangladesh
# Got series code for Bulgaria
# Got series code for Bahrain
# Got series code for Bahamas
# Got series code for Bosnia and Herzegovina
# No series code for Saint Barthélemy
# Got series code for Belarus
# Got series code for Belize
# Got series code for Bermuda
# Got series code for Bolivia, Plurinational State of
# Got series code for Brazil
# Got series code for Barbados
# Got series code for Brunei Darussalam
# Got series code for Bhutan
# No series code for Bouvet Island
# Got series code for Botswana
# Got series code for Central African Republic
# Got series code for Canada
# No series code for Cocos (Keeling) Islands
# Got series code for Switzerland
# Got series code for Chile
# Got series code for China
# Got series code for Côte d'Ivoire
# Got series code for Cameroon
# Got series code for Congo, The Democratic Republic of the
# Got series code for Congo
# No series code for Cook Islands
# Got series code for Colombia
# Got series code for Comoros
# Got series code for Cabo Verde
# Got series code for Costa Rica
# No series code for Cuba
# No series code for Curaçao
# No series code for Christmas Island
# No series code for Cayman Islands
# Got series code for Cyprus
# No series code for Czechia
# Got series code for Germany
# Got series code for Djibouti
# Got series code for Dominica
# Got series code for Denmark
# Got series code for Dominican Republic
# No series code for Algeria
# Got series code for Ecuador
# Got series code for Egypt
# No series code for Eritrea
# No series code for Western Sahara
# Got series code for Spain
# Got series code for Estonia
# Got series code for Ethiopia
# Got series code for Finland
# Got series code for Fiji
# No series code for Falkland Islands (Malvinas)
# Got series code for France
# No series code for Faroe Islands
# No series code for Micronesia, Federated States of
# Got series code for Gabon
# Got series code for United Kingdom
# Got series code for Georgia
# No series code for Guernsey
# Got series code for Ghana
# No series code for Gibraltar
# Got series code for Guinea
# No series code for Guadeloupe
# Got series code for Gambia
# Got series code for Guinea-Bissau
# Got series code for Equatorial Guinea
# Got series code for Greece
# Got series code for Grenada
# No series code for Greenland
# Got series code for Guatemala
# No series code for French Guiana
# No series code for Guam
# No series code for Guyana
# Got series code for Hong Kong
# No series code for Heard Island and McDonald Islands
# Got series code for Honduras
# Got series code for Croatia
# No series code for Haiti
# Got series code for Hungary
# Got series code for Indonesia
# No series code for Isle of Man
# Got series code for India
# No series code for British Indian Ocean Territory
# Got series code for Ireland
# Got series code for Iran, Islamic Republic of
# Got series code for Iraq
# Got series code for Iceland
# Got series code for Israel
# Got series code for Italy
# Got series code for Jamaica
# Got series code for Jersey
# Got series code for Jordan
# Got series code for Japan
# Got series code for Kazakhstan
# Got series code for Kenya
# Got series code for Kyrgyzstan
# Got series code for Cambodia
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18272\2226802256.py in <module>
#      18     # extract the series ID if the search returned results
#      19     # check if there are any series codes returned
# ---> 20     if len(response['seriess']) > 0:
#      21         series = response['seriess'][0]
#      22         id = series['id']
#
# KeyError: 'seriess'

# %%
results = []

# loop through each usable country and get the GDP data
for country, series_code in usable_countries:
    url = f"https://api.stlouisfed.org/fred/series/observations?series_id={series_code}&api_key={fred_api_key}&file_type=json"
    response = requests.get(url)
    data = response.json()
    # loop through each observation in the data and add it to the results list
    for observation in data['observations']:
        date = observation['date']
        bt = observation['value']
        if date >= '2018' and date <= '2022':
            results.append({
                "country": country,
                "series_code": series_code,
                "date": date,
                "Balance of Trade": bt
            })
BalanceofTrade = pd.DataFrame(results)
BalanceofTrade
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18272\3067068541.py in <module>
#       2
#       3 # loop through each usable country and get the GDP data
# ----> 4 for country, series_code in usable_countries:
#       5     url = f"https://api.stlouisfed.org/fred/series/observations?series_id={series_code}&api_key={fred_api_key}&file_type=json"
#       6     response = requests.get(url)
#
# NameError: name 'usable_countries' is not defined
