# %%
#Anthony
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np

# %%
GDP_growth_df = pd.read_csv('merged.csv')

# %%
GDP_growth_df.head(10)
# Out:
#    Unnamed: 0      country  ISO  year  population           GDP  inflation
# 0           2  Afghanistan  AFG  2020  38972230.0  2.014344e+10        NaN  \
# 1           3  Afghanistan  AFG  2021  40099462.0  1.478686e+10        NaN
# 2           4      Albania  ALB  2018   2866376.0  1.515643e+10   2.028060
# 3           5      Albania  ALB  2019   2854191.0  1.540183e+10   1.411091
# 4          28    Argentina  ARG  2018  44494502.0  5.248197e+11        NaN
# 5          29    Argentina  ARG  2019  44938712.0  4.477546e+11        NaN
# 6          30    Argentina  ARG  2020  45376763.0  3.855402e+11        NaN
# 7          31    Argentina  ARG  2021  45808747.0  4.872273e+11        NaN
# 8          32      Armenia  ARM  2018   2836557.0  1.245794e+10   2.520234
# 9          33      Armenia  ARM  2019   2820602.0  1.361929e+10   1.443447
#
#    unemployment    GDP_change  ConfirmedCases  ConfirmedDeaths  CasesPer1k
# 0         11.71  5.356581e+09         52330.0           2189.0    1.320850  \
# 1          5.58           NaN        158084.0           7356.0    3.895567
# 2         12.30 -2.453984e+08             NaN              NaN         NaN
# 3         11.47  2.699645e+08             NaN              NaN         NaN
# 4          9.22  7.706513e+10             NaN              NaN         NaN
# 5          9.84  6.221438e+10             NaN              NaN         NaN
# 6         11.46 -1.016871e+11       1625514.0          43245.0   35.991665
# 7          8.74           NaN       5654408.0         117169.0  124.574044
# 8         13.21 -1.161349e+09             NaN              NaN         NaN
# 9         12.20  9.775938e+08             NaN              NaN         NaN
#
#    DeathsPer1k  PopulationVaccinated  StringencyIndex
# 0     0.055252                  0.00        50.400873  \
# 1     0.181269                  9.13        29.242219
# 2          NaN                   NaN              NaN
# 3          NaN                   NaN              NaN
# 4          NaN                   NaN              NaN
# 5          NaN                   NaN              NaN
# 6     0.957518                  0.00        87.617527
# 7     2.581387                 67.62        66.841315
# 8          NaN                   NaN              NaN
# 9          NaN                   NaN              NaN
#
#    GovernmentResponseIndex  ContainmentHealthIndex  EconomicSupportIndex
# 0                41.275527               46.769891              2.818182
# 1                24.306740               27.781370              0.000000
# 2                      NaN                     NaN                   NaN
# 3                      NaN                     NaN                   NaN
# 4                      NaN                     NaN                   NaN
# 5                      NaN                     NaN                   NaN
# 6                76.753564               77.005418             75.000000
# 7                64.280274               67.112767             44.452055
# 8                      NaN                     NaN                   NaN
# 9                      NaN                     NaN                   NaN

# %%
print(GDP_growth_df.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'ISO', 'year', 'population', 'GDP',
#        'inflation', 'unemployment', 'GDP_change', 'ConfirmedCases',
#        'ConfirmedDeaths', 'CasesPer1k', 'DeathsPer1k', 'PopulationVaccinated',
#        'StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'EconomicSupportIndex'],
#       dtype='object')

# %%
GDP_growth_df = GDP_growth_df.drop(['PopulationVaccinated','population','GDP','GDP_change','inflation', 'unemployment','StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex', 'EconomicSupportIndex'], axis=1)
GDP_growth_df.head(10)
# Out:
#    Unnamed: 0      country  ISO  year  ConfirmedCases  ConfirmedDeaths
# 0           2  Afghanistan  AFG  2020         52330.0           2189.0  \
# 1           3  Afghanistan  AFG  2021        158084.0           7356.0
# 2           4      Albania  ALB  2018             NaN              NaN
# 3           5      Albania  ALB  2019             NaN              NaN
# 4          28    Argentina  ARG  2018             NaN              NaN
# 5          29    Argentina  ARG  2019             NaN              NaN
# 6          30    Argentina  ARG  2020       1625514.0          43245.0
# 7          31    Argentina  ARG  2021       5654408.0         117169.0
# 8          32      Armenia  ARM  2018             NaN              NaN
# 9          33      Armenia  ARM  2019             NaN              NaN
#
#    CasesPer1k  DeathsPer1k
# 0    1.320850     0.055252
# 1    3.895567     0.181269
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
# 5         NaN          NaN
# 6   35.991665     0.957518
# 7  124.574044     2.581387
# 8         NaN          NaN
# 9         NaN          NaN

# %%
# Filter the dataframe to include only the rows with year 2020 and 2021
clean_2020_df = GDP_growth_df[GDP_growth_df['year'] == 2020]
clean_2020_df = clean_2020_df.drop('year', axis=1)
# Display the updated dataframe with the new column
print(clean_2020_df.head(10))
# Out:
#     Unnamed: 0      country  ISO  ConfirmedCases  ConfirmedDeaths  CasesPer1k
# 0            2  Afghanistan  AFG         52330.0           2189.0    1.320850  \
# 6           30    Argentina  ARG       1625514.0          43245.0   35.991665
# 10          34      Armenia  ARM             NaN              NaN         NaN
# 13          42    Australia  AUS         28425.0            909.0    1.101918
# 17          46      Austria  AUT        356063.0           7486.0   39.942238
# 21          50   Azerbaijan  AZE        218700.0           2641.0   21.240487
# 28          70      Belarus  BLR        194284.0           1424.0   20.224356
# 32          74      Belgium  BEL        646496.0          19528.0   55.818258
# 39          90       Bhutan  BTN           670.0              0.0    0.864507
# 43          94      Bolivia  BOL        160124.0           9165.0   13.332581
#
#     DeathsPer1k
# 0      0.055252
# 6      0.957518
# 10          NaN
# 13     0.035238
# 17     0.839760
# 21     0.256498
# 28     0.148234
# 32     1.686041
# 39     0.000000
# 43     0.763115

# %%
critical_indicators_df = pd.read_csv('Five_critical_indicators.csv')

# %%
critical_indicators_df = clean_2020_df.merge(critical_indicators_df, on="ISO", how="inner")
critical_indicators_df.head(20)
# Out:
#     Unnamed: 0                 country  ISO  ConfirmedCases  ConfirmedDeaths
# 0            2             Afghanistan  AFG         52330.0           2189.0  \
# 1           30               Argentina  ARG       1625514.0          43245.0
# 2           34                 Armenia  ARM             NaN              NaN
# 3           42               Australia  AUS         28425.0            909.0
# 4           46                 Austria  AUT        356063.0           7486.0
# 5           50              Azerbaijan  AZE        218700.0           2641.0
# 6           70                 Belarus  BLR        194284.0           1424.0
# 7           74                 Belgium  BEL        646496.0          19528.0
# 8           90                  Bhutan  BTN           670.0              0.0
# 9           94                 Bolivia  BOL        160124.0           9165.0
# 10          98  Bosnia and Herzegovina  BIH        110985.0           4050.0
# 11         102                Botswana  BWA         14805.0             42.0
# 12         106                  Brazil  BRA       7681032.0         195072.0
# 13         114       Brunei Darussalam  BRN             NaN              NaN
# 14         118                Bulgaria  BGR        202266.0           7576.0
# 15         126                 Burundi  BDI           818.0              2.0
# 16         138                  Canada  CAN        590249.0          15736.0
# 17         158                   Chile  CHL        608973.0          16608.0
# 18         162                   China  CHN         93679.0           4733.0
# 19         166                Colombia  COL       1642775.0          43213.0
#
#     CasesPer1k  DeathsPer1k                 Country  Econ growth 2020
# 0     1.320850     0.055252             Afghanistan             -2.35  \
# 1    35.991665     0.957518               Argentina             -9.94
# 2          NaN          NaN                 Armenia             -7.20
# 3     1.101918     0.035238               Australia             -0.05
# 4    39.942238     0.839760                 Austria             -6.45
# 5    21.240487     0.256498              Azerbaijan             -4.30
# 6    20.224356     0.148234                 Belarus             -0.70
# 7    55.818258     1.686041                 Belgium             -5.36
# 8     0.864507     0.000000                  Bhutan            -10.01
# 9    13.332581     0.763115                 Bolivia             -8.74
# 10   33.674258     1.228821  Bosnia and Herzegovina             -3.12
# 11    5.762353     0.016347                Botswana             -8.73
# 12   35.921600     0.912286                  Brazil             -3.88
# 13         NaN          NaN                  Brunei              1.13
# 14   29.152879     1.091939                Bulgaria             -3.96
# 15    0.066039     0.000161                 Burundi              0.33
# 16   15.525033     0.413896                  Canada             -5.23
# 17   31.400168     0.856350                   Chile             -5.98
# 18    0.065700     0.003319                   China              2.24
# 19   32.057714     0.843274                Colombia             -7.05
#
#     Econ growth 2021  Avg Econ Growth  Exports pct of GDP_2019
# 0             -20.74          -11.545                      NaN  \
# 1              10.40            0.230                    17.92
# 2               5.70           -0.750                    41.35
# 3               2.24            1.095                    24.15
# 4               4.56           -0.945                    55.76
# 5               5.60            0.650                    49.05
# 6               2.30            0.800                    65.09
# 7               6.13            0.385                    82.40
# 8               4.09           -2.960                    33.94
# 9               6.11           -1.315                    24.97
# 10              7.55            2.215                    40.59
# 11             11.37            1.320                    37.15
# 12              4.62            0.370                    14.12
# 13             -1.59           -0.230                    57.95
# 14              7.63            1.835                    63.93
# 15              1.80            1.065                     5.17
# 16              4.54           -0.345                    31.91
# 17             11.67            2.845                    27.83
# 18              8.11            5.175                    18.41
# 19             10.68            1.815                    15.87
#
#     External debt pct GDP_2019  Corruption Index 100_2019
# 0                        13.94                       16.0  \
# 1                        64.52                       45.0
# 2                        86.13                       42.0
# 3                          NaN                       77.0
# 4                          NaN                       77.0
# 5                        34.21                       30.0
# 6                        65.18                       45.0
# 7                          NaN                       75.0
# 8                       117.25                       68.0
# 9                        35.71                       31.0
# 10                       63.09                       36.0
# 11                        9.89                       61.0
# 12                       31.32                       35.0
# 13                         NaN                       60.0
# 14                       60.48                       43.0
# 15                       24.03                       19.0
# 16                         NaN                       77.0
# 17                         NaN                       67.0
# 18                       14.85                       41.0
# 19                       43.95                       37.0
#
#     Int tourism pct GDP_2019
# 0                       0.45
# 1                       1.26
# 2                      11.40
# 3                       3.44
# 4                       5.83
# 5                       4.16
# 6                       2.00
# 7                       1.97
# 8                       4.73
# 9                       2.39
# 10                      6.06
# 11                      4.27
# 12                      0.33
# 13                       NaN
# 14                      7.01
# 15                       NaN
# 16                       NaN
# 17                      1.18
# 18                       NaN
# 19                      2.10

# %%
print(critical_indicators_df.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'ISO', 'ConfirmedCases', 'ConfirmedDeaths',
#        'CasesPer1k', 'DeathsPer1k', 'Country', 'Econ growth 2020',
#        'Econ growth 2021', 'Avg Econ Growth', 'Exports pct of GDP_2019',
#        'External debt pct GDP_2019', 'Corruption Index 100_2019',
#        'Int tourism pct GDP_2019'],
#       dtype='object')

# %%
# Sort the dataframe by GDP_change_pct in descending order and select top 15 rows
top_gdp_df = critical_indicators_df.sort_values(by='Econ growth 2020', ascending=False).head(20)

# Sort the dataframe by GDP_change_pct in ascending order and select top 15 rows
bottom_gdp_df = critical_indicators_df.sort_values(by='Econ growth 2020', ascending=True).head(20)

# %%
top_gdp_df
# Out:
#      Unnamed: 0                       country  ISO  ConfirmedCases
# 42          362                       Ireland  IRL         91779.0  \
# 27          226                         Egypt  EGY        138062.0
# 41          354     Iran, Islamic Republic of  IRN             NaN
# 66          530                       Myanmar  MMR        124630.0
# 102         834                      Viet Nam  VNM             NaN
# 18          162                         China  CHN         93679.0
# 93          754  Tanzania, United Republic of  TZA             NaN
# 96          782                        Turkey  TUR       2208652.0
# 101         822                    Uzbekistan  UZB         77060.0
# 20          178             Congo, (Kinshasa)  COD             NaN
# 13          114             Brunei Darussalam  BRN             NaN
# 57          466                        Malawi  MWI          6583.0
# 15          126                       Burundi  BDI           818.0
# 53          446                     Lithuania  LTU        145052.0
# 3            42                     Australia  AUS         28425.0
# 49          398                      Kiribati  KIR             0.0
# 29          242                       Estonia  EST         27990.0
# 6            70                       Belarus  BLR        194284.0
# 50          406                 Korea (South)  KOR             NaN
# 56          458        Macedonia, Republic of  MKD             NaN
#
#      ConfirmedDeaths  CasesPer1k  DeathsPer1k
# 42            2237.0   18.477143     0.450358  \
# 27            7631.0    1.273734     0.070402
# 41               NaN         NaN          NaN
# 66            2682.0    2.324388     0.050020
# 102              NaN         NaN          NaN
# 18            4733.0    0.065700     0.003319
# 93               NaN         NaN          NaN
# 96           20881.0   26.150528     0.247232
# 101            614.0    2.279217     0.018160
# 20               NaN         NaN          NaN
# 13               NaN         NaN          NaN
# 57             189.0    0.335299     0.009627
# 15               2.0    0.066039     0.000161
# 53            1800.0   51.718710     0.641795
# 3              909.0    1.101918     0.035238
# 49               0.0    0.000000     0.000000
# 29             229.0   21.048246     0.172206
# 6             1424.0   20.224356     0.148234
# 50               NaN         NaN          NaN
# 56               NaN         NaN          NaN
#
#                               Country  Econ growth 2020  Econ growth 2021
# 42                            Ireland              6.18             13.59  \
# 27                              Egypt              3.57              3.33
# 41                               Iran              3.33              4.72
# 66                    Burma (Myanmar)              3.17            -17.91
# 102                           Vietnam              2.87              2.56
# 18                              China              2.24              8.11
# 93                           Tanzania              2.00              4.28
# 96                             Turkey              1.94             11.35
# 101                        Uzbekistan              1.89              7.42
# 20   Democratic Republic of the Congo              1.74              6.20
# 13                             Brunei              1.13             -1.59
# 57                             Malawi              0.80              2.75
# 15                            Burundi              0.33              1.80
# 53                          Lithuania             -0.02              5.98
# 3                           Australia             -0.05              2.24
# 49                           Kiribati             -0.55              1.50
# 29                            Estonia             -0.55              8.01
# 6                             Belarus             -0.70              2.30
# 50                        South Korea             -0.71              4.15
# 56                    North Macedonia             -0.72              3.88
#
#      Avg Econ Growth  Exports pct of GDP_2019  External debt pct GDP_2019
# 42             9.885                   127.88                         NaN  \
# 27             3.450                    17.50                       39.20
# 41             4.025                    23.48                        1.67
# 66            -7.370                    30.39                       16.84
# 102            2.715                    85.16                       37.42
# 18             5.175                    18.41                       14.85
# 93             3.140                    16.01                       39.05
# 96             6.645                    32.53                       59.42
# 101            4.655                    28.42                       36.95
# 20             3.970                    25.87                       15.46
# 13            -0.230                    57.95                         NaN
# 57             1.775                      NaN                       22.40
# 15             1.065                     5.17                       24.03
# 53             2.980                    77.32                         NaN
# 3              1.095                    24.15                         NaN
# 49             0.475                    18.27                         NaN
# 29             3.730                    73.88                         NaN
# 6              0.800                    65.09                       65.18
# 50             1.720                    39.28                         NaN
# 56             1.580                    62.41                       74.85
#
#      Corruption Index 100_2019  Int tourism pct GDP_2019
# 42                        74.0                      3.71
# 27                        35.0                      4.70
# 41                        26.0                       NaN
# 66                        29.0                      3.64
# 102                       37.0                      3.54
# 18                        41.0                       NaN
# 93                        37.0                      4.29
# 96                        39.0                      5.45
# 101                       25.0                      2.80
# 20                        18.0                       NaN
# 13                        60.0                       NaN
# 57                        31.0                      0.56
# 15                        19.0                       NaN
# 53                        60.0                       NaN
# 3                         77.0                      3.44
# 49                         NaN                       NaN
# 29                        74.0                      7.43
# 6                         45.0                      2.00
# 50                        59.0                      1.54
# 56                        35.0                      3.18

# %%
bottom_gdp_df
# Out:
#     Unnamed: 0           country  ISO  ConfirmedCases  ConfirmedDeaths
# 55         454  Macao, SAR China  MAC             NaN              NaN  \
# 81         646       Saint Lucia  LCA             NaN              NaN
# 71         594            Panama  PAN        246790.0           4022.0
# 65         518        Montenegro  MNE             NaN              NaN
# 61         494         Mauritius  MUS           527.0             10.0
# 89         718             Spain  ESP       1928265.0          50837.0
# 73         606              Peru  PER       1015137.0          93070.0
# 8           90            Bhutan  BTN           670.0              0.0
# 45         378           Jamaica  JAM         12827.0            302.0
# 1           30         Argentina  ARG       1625514.0          43245.0
# 74         610       Philippines  PHL        474064.0           9244.0
# 44         374             Italy  ITA       2107166.0          74159.0
# 34         294            Greece  GRC        138850.0           4838.0
# 35         330          Honduras  HND        121827.0           3130.0
# 9           94           Bolivia  BOL        160124.0           9165.0
# 11         102          Botswana  BWA         14805.0             42.0
# 21         186           Croatia  HRV        210837.0           3920.0
# 51         414        Kyrgyzstan  KGZ             NaN              NaN
# 60         482             Malta  MLT         12774.0            219.0
# 76         618          Portugal  PRT        413678.0           6906.0
#
#     CasesPer1k  DeathsPer1k      Country  Econ growth 2020  Econ growth 2021
# 55         NaN          NaN        Macao            -54.24             19.27  \
# 81         NaN          NaN  Saint Lucia            -24.36             12.23
# 71   57.084343     0.930318       Panama            -17.94             15.34
# 65         NaN          NaN   Montenegro            -15.31             12.43
# 61    0.405792     0.007700    Mauritius            -14.60              3.70
# 89   40.682705     1.072563        Spain            -11.33              5.52
# 73   30.285211     2.776615         Peru            -10.95             13.35
# 8     0.864507     0.000000       Bhutan            -10.01              4.09
# 45    4.538285     0.106850      Jamaica            -10.00              4.60
# 1    35.991665     0.957518    Argentina             -9.94             10.40
# 74    4.191757     0.081737  Philippines             -9.52              5.70
# 44   35.497327     1.249283        Italy             -9.04              6.74
# 34   13.247633     0.461592       Greece             -9.00              8.43
# 35   11.941791     0.306811     Honduras             -8.96             12.53
# 9    13.332581     0.763115      Bolivia             -8.74              6.11
# 11    5.762353     0.016347     Botswana             -8.73             11.37
# 21   51.687137     0.960996      Croatia             -8.58             13.07
# 51         NaN          NaN   Kyrgyzstan             -8.40              3.61
# 60   24.512541     0.420248        Malta             -8.32             10.30
# 76   40.170775     0.670617     Portugal             -8.30              5.48
#
#     Avg Econ Growth  Exports pct of GDP_2019  External debt pct GDP_2019
# 55          -17.485                    82.52                         NaN  \
# 81           -6.065                      NaN                       32.19
# 71           -1.300                    41.21                         NaN
# 65           -1.440                    43.85                      153.17
# 61           -5.450                    44.07                       78.62
# 89           -2.905                    34.91                         NaN
# 73            1.200                    24.04                       29.19
# 8            -2.960                    33.94                      117.25
# 45           -2.700                    38.04                      113.28
# 1             0.230                    17.92                       64.52
# 74           -1.910                    28.38                       20.17
# 44           -1.150                    31.60                         NaN
# 34           -0.285                    40.11                         NaN
# 35            1.785                    39.92                       42.18
# 9            -1.315                    24.97                       35.71
# 11            1.320                    37.15                        9.89
# 21            2.245                    50.59                         NaN
# 51           -2.395                    35.23                      104.50
# 60            0.990                   146.09                         NaN
# 76           -1.410                    43.51                         NaN
#
#     Corruption Index 100_2019  Int tourism pct GDP_2019
# 55                        NaN                     74.57
# 81                       55.0                       NaN
# 71                       36.0                     10.53
# 65                       45.0                     23.02
# 61                        NaN                     14.02
# 89                       62.0                       NaN
# 73                       36.0                      2.06
# 8                        68.0                      4.73
# 45                       43.0                       NaN
# 1                        45.0                      1.26
# 74                       34.0                      3.04
# 44                       53.0                      2.58
# 34                       48.0                     11.21
# 35                       26.0                      2.22
# 9                        31.0                      2.39
# 11                       61.0                      4.27
# 21                       47.0                     19.21
# 51                       30.0                      7.98
# 60                       54.0                       NaN
# 76                       62.0                     10.25

# %% [markdown]
# # Scatter Plots for Economic Growth vs Covid numbers vs Critical Indicators

# %% [markdown]
# Economic Growth vs Covid numbers for Top performers

# %%
# scatter plot for Top Economic Growth vs. Covid cases per 1K
plt.scatter(top_gdp_df["Econ growth 2020"], top_gdp_df["CasesPer1k"], marker="o", edgecolor="black",color="blue")

# Incorporate the other graph properties
plt.title("Economic Growth vs. Covid Cases per 1K")
plt.xlabel("Economic Growth")
plt.ylabel("Covid Cases per 1K")
plt.xlim(min(top_gdp_df["Econ growth 2020"])-2, max(top_gdp_df["Econ growth 2020"])+2)
plt.ylim(min(top_gdp_df["CasesPer1k"])-10, max(top_gdp_df["CasesPer1k"])+10)


# Show plot
plt.show()

# %% [markdown]
# Linear Regression on Economic Growth vs Covid numbers for Top performers

# %%
# Linear regression on Top performers with covid cases

valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['CasesPer1k'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["CasesPer1k"]
xlabel = "Economic Growth"
ylabel = "Cases Per 1K"
title = "Top Economic Growth vs. Covid Cases"
text_coordinates = (3.5, 40)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %% [markdown]
# With a R value of 0.128, the linear regression clearly shows there is no correlation between Top economic growth & covid cases

# %% [markdown]
# Linear Regression- Top Economic Growth vs Covid Deaths

# %%
# Linear regression on Top performers with covid cases
valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['DeathsPer1k'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["DeathsPer1k"]
xlabel = "Economic Growth"
ylabel = "Deaths Per 1K"
title = "Top Economic Growth vs. Covid Deaths"
text_coordinates = (3, 0.6)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %% [markdown]
# With a R value of 0.189, the linear regression clearly shows there is no correlation between Top economic growth & covid Deaths

# %% [markdown]
# Linear Regression- Bottom Economic Growth vs Covid cases

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['CasesPer1k'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["CasesPer1k"]
xlabel = "Economic Growth"
ylabel = "Cases Per 1K"
title = "Top Economic Growth vs. Covid cases"
text_coordinates = (-18, 10)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %% [markdown]
# With a R value of 0.242, the linear regression clearly shows there is no correlation between Poor economic growth & covid Cases

# %% [markdown]
# Linear Regression- Bottom Economic Growth vs Covid Deaths

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['DeathsPer1k'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["DeathsPer1k"]
xlabel = "Economic Growth"
ylabel = "Deaths Per 1K"
title = "Top Economic Growth vs. Covid Deaths"
text_coordinates = (-18, 2.5)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %% [markdown]
# The R value and linear Regression of all four plots show that there is no correlation between covid cases and deaths with the economic performance of these countries. Now lets move on to critical economic indicators which could have impacted the economic performance.

# %% [markdown]
# Top Economic growth vs export as percentage of GDP

# %%
# Linear regression on Top performers with covid cases
valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['Exports pct of GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["Exports pct of GDP_2019"]
xlabel = "Economic Growth"
ylabel = "Exports pct of GDP_2019"
title = "Top Economic Growth vs. Exports pct of GDP_2019"
text_coordinates = (3, 0.6)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['Exports pct of GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["Exports pct of GDP_2019"]
xlabel = "Economic Growth"
ylabel = "Exports pct of GDP_2019"
title = "Bottom Economic Growth vs. Exports pct of GDP_2019"
text_coordinates = (-50, 130)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['External debt pct GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["External debt pct GDP_2019"]
xlabel = "Economic Growth"
ylabel = "External debt pct GDP_2019"
title = "Top Economic Growth vs. External debt pct GDP_2019"
text_coordinates = (2, 0.6)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['External debt pct GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["External debt pct GDP_2019"]
xlabel = "Economic Growth"
ylabel = "External debt pct GDP_2019"
title = "Bottom Economic Growth vs. External debt pct GDP_2019"
text_coordinates = (-24, 140)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['Corruption Index 100_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["Corruption Index 100_2019"]
xlabel = "Economic Growth"
ylabel = "Corruption Index 100_2019"
title = "Top Economic Growth vs. Corruption Index 100_2019"
text_coordinates = (3, 70)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['Corruption Index 100_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["Corruption Index 100_2019"]
xlabel = "Economic Growth"
ylabel = "Corruption Index 100_2019"
title = "Bottom Economic Growth vs. Corruption Index 100_2019"
text_coordinates = (-24, 65)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_top_df = top_gdp_df[np.isfinite(top_gdp_df['Econ growth 2020']) & np.isfinite(top_gdp_df['Int tourism pct GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_top_df["Econ growth 2020"]
y_values = valid_top_df["Int tourism pct GDP_2019"]
xlabel = "Economic Growth"
ylabel = "Int tourism pct GDP_2019"
title = "Top Economic Growth vs. Int tourism pct GDP_2019"
text_coordinates = (3, 6)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Top performers with covid cases
valid_bottom_df = bottom_gdp_df[np.isfinite(bottom_gdp_df['Econ growth 2020']) & np.isfinite(bottom_gdp_df['Int tourism pct GDP_2019'])]
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,3)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = valid_bottom_df["Econ growth 2020"]
y_values = valid_bottom_df["Int tourism pct GDP_2019"]
xlabel = "Economic Growth"
ylabel = "Int tourism pct GDP_2019"
title = "Bottom Economic Growth vs. Int tourism pct GDP_2019"
text_coordinates = (-24, 65)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)
