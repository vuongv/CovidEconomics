# %%
#Anthony
import pandas as pd

# %%
GDP_growth_df = pd.read_csv('merged.csv')

# %%
GDP_growth_df.head(10)
# Out:
#    Unnamed: 0      country  ISO  year  population           GDP  inflation
# 0           2  Afghanistan  AFG  2020  38972230.0  2.014344e+10        NaN  \
# 1           3  Afghanistan  AFG  2021  40099462.0  1.478686e+10        NaN
# 2           4      Albania  ALB  2018   2866376.0  1.515643e+10   2.028060
# 3           5      Albania  ALB  2019   2854191.0  1.540183e+10   1.411091
# 4          28    Argentina  ARG  2018  44494502.0  5.248197e+11        NaN
# 5          29    Argentina  ARG  2019  44938712.0  4.477546e+11        NaN
# 6          30    Argentina  ARG  2020  45376763.0  3.855402e+11        NaN
# 7          31    Argentina  ARG  2021  45808747.0  4.872273e+11        NaN
# 8          32      Armenia  ARM  2018   2836557.0  1.245794e+10   2.520234
# 9          33      Armenia  ARM  2019   2820602.0  1.361929e+10   1.443447
#
#    unemployment    GDP_change  ConfirmedCases  ConfirmedDeaths  CasesPer1k
# 0         11.71  5.356581e+09         52330.0           2189.0    1.320850  \
# 1          5.58           NaN        158084.0           7356.0    3.895567
# 2         12.30 -2.453984e+08             NaN              NaN         NaN
# 3         11.47  2.699645e+08             NaN              NaN         NaN
# 4          9.22  7.706513e+10             NaN              NaN         NaN
# 5          9.84  6.221438e+10             NaN              NaN         NaN
# 6         11.46 -1.016871e+11       1625514.0          43245.0   35.991665
# 7          8.74           NaN       5654408.0         117169.0  124.574044
# 8         13.21 -1.161349e+09             NaN              NaN         NaN
# 9         12.20  9.775938e+08             NaN              NaN         NaN
#
#    DeathsPer1k  PopulationVaccinated  StringencyIndex
# 0     0.055252                  0.00        50.400873  \
# 1     0.181269                  9.13        29.242219
# 2          NaN                   NaN              NaN
# 3          NaN                   NaN              NaN
# 4          NaN                   NaN              NaN
# 5          NaN                   NaN              NaN
# 6     0.957518                  0.00        87.617527
# 7     2.581387                 67.62        66.841315
# 8          NaN                   NaN              NaN
# 9          NaN                   NaN              NaN
#
#    GovernmentResponseIndex  ContainmentHealthIndex  EconomicSupportIndex
# 0                41.275527               46.769891              2.818182
# 1                24.306740               27.781370              0.000000
# 2                      NaN                     NaN                   NaN
# 3                      NaN                     NaN                   NaN
# 4                      NaN                     NaN                   NaN
# 5                      NaN                     NaN                   NaN
# 6                76.753564               77.005418             75.000000
# 7                64.280274               67.112767             44.452055
# 8                      NaN                     NaN                   NaN
# 9                      NaN                     NaN                   NaN

# %%
print(GDP_growth_df.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'ISO', 'year', 'population', 'GDP',
#        'inflation', 'unemployment', 'GDP_change', 'ConfirmedCases',
#        'ConfirmedDeaths', 'CasesPer1k', 'DeathsPer1k', 'PopulationVaccinated',
#        'StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex',
#        'EconomicSupportIndex'],
#       dtype='object')

# %%
GDP_growth_df = GDP_growth_df.drop(['PopulationVaccinated', 'ISO','StringencyIndex', 'GovernmentResponseIndex', 'ContainmentHealthIndex', 'EconomicSupportIndex'], axis=1)
GDP_growth_df.head(10)
# Out:
#    Unnamed: 0      country  year  population           GDP  inflation
# 0           2  Afghanistan  2020  38972230.0  2.014344e+10        NaN  \
# 1           3  Afghanistan  2021  40099462.0  1.478686e+10        NaN
# 2           4      Albania  2018   2866376.0  1.515643e+10   2.028060
# 3           5      Albania  2019   2854191.0  1.540183e+10   1.411091
# 4          28    Argentina  2018  44494502.0  5.248197e+11        NaN
# 5          29    Argentina  2019  44938712.0  4.477546e+11        NaN
# 6          30    Argentina  2020  45376763.0  3.855402e+11        NaN
# 7          31    Argentina  2021  45808747.0  4.872273e+11        NaN
# 8          32      Armenia  2018   2836557.0  1.245794e+10   2.520234
# 9          33      Armenia  2019   2820602.0  1.361929e+10   1.443447
#
#    unemployment    GDP_change  ConfirmedCases  ConfirmedDeaths  CasesPer1k
# 0         11.71  5.356581e+09         52330.0           2189.0    1.320850  \
# 1          5.58           NaN        158084.0           7356.0    3.895567
# 2         12.30 -2.453984e+08             NaN              NaN         NaN
# 3         11.47  2.699645e+08             NaN              NaN         NaN
# 4          9.22  7.706513e+10             NaN              NaN         NaN
# 5          9.84  6.221438e+10             NaN              NaN         NaN
# 6         11.46 -1.016871e+11       1625514.0          43245.0   35.991665
# 7          8.74           NaN       5654408.0         117169.0  124.574044
# 8         13.21 -1.161349e+09             NaN              NaN         NaN
# 9         12.20  9.775938e+08             NaN              NaN         NaN
#
#    DeathsPer1k
# 0     0.055252
# 1     0.181269
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6     0.957518
# 7     2.581387
# 8          NaN
# 9          NaN

# %%
# Filter the dataframe to include only the rows with year 2019 and 2021
GDP_growth_df_2019 = GDP_growth_df[GDP_growth_df['year'] == 2019]
GDP_growth_df_2021 = GDP_growth_df[GDP_growth_df['year'] == 2021]

# Merge the 2019 and 2021 dataframes based on the country column
growth_merged_df = GDP_growth_df_2019.merge(GDP_growth_df_2021, on='country', suffixes=('_2019', '_2021'))

# Calculate the percentage change in GDP and store it in a new column 'GDP_change_pct'
growth_merged_df['GDP_change_pct'] = ((growth_merged_df['GDP_2021'] - growth_merged_df['GDP_2019']) / growth_merged_df['GDP_2019']) * 100

# Display the updated dataframe with the new column
print(growth_merged_df.head(10))
# Out:
#    Unnamed: 0_2019                 country  year_2019  population_2019
# 0               29               Argentina       2019       44938712.0  \
# 1               41               Australia       2019       25340217.0
# 2               45                 Austria       2019        8879920.0
# 3               49              Azerbaijan       2019       10024283.0
# 4               69                 Belarus       2019        9419758.0
# 5               73                 Belgium       2019       11488980.0
# 6               77                  Belize       2019         389095.0
# 7               89                  Bhutan       2019         767459.0
# 8               93                 Bolivia       2019       11777315.0
# 9               97  Bosnia and Herzegovina       2019        3360711.0
#
#        GDP_2019  inflation_2019  unemployment_2019  GDP_change_2019
# 0  4.477546e+11             NaN               9.84     6.221438e+10  \
# 1  1.392228e+12        1.610768               5.16     6.532681e+10
# 2  4.446212e+11        1.530896               4.56     9.395938e+09
# 3  4.817424e+10        2.610572               4.85     5.481235e+09
# 4  6.440965e+10        5.598156               4.16     3.038521e+09
# 5  5.358309e+11        1.436820               5.36     1.061907e+10
# 6  2.416500e+09        0.187069               9.05     3.365000e+08
# 7  2.535657e+09        2.725821               2.72     2.104726e+08
# 8  4.089532e+10        1.839545               3.68     4.265479e+09
# 9  2.020248e+10        0.562782              15.69     2.520084e+08
#
#    ConfirmedCases_2019  ConfirmedDeaths_2019  ...  population_2021
# 0                  NaN                   NaN  ...       45808747.0  \
# 1                  NaN                   NaN  ...       25688079.0
# 2                  NaN                   NaN  ...        8955797.0
# 3                  NaN                   NaN  ...       10137750.0
# 4                  NaN                   NaN  ...        9340314.0
# 5                  NaN                   NaN  ...       11592952.0
# 6                  NaN                   NaN  ...         400031.0
# 7                  NaN                   NaN  ...         777486.0
# 8                  NaN                   NaN  ...       12079472.0
# 9                  NaN                   NaN  ...        3270943.0
#
#        GDP_2021  inflation_2021  unemployment_2021  GDP_change_2021
# 0  4.872273e+11             NaN               8.74              NaN  \
# 1  1.552667e+12        2.863910               5.12              NaN
# 2  4.803684e+11        2.766667               6.46              NaN
# 3  5.462218e+10        6.650299               5.95              NaN
# 4  6.820538e+10        9.460284               3.90              NaN
# 5  5.941042e+11        2.440249               6.26              NaN
# 6  2.491500e+09        3.235637              10.16              NaN
# 7  2.539553e+09        7.346839               4.80              NaN
# 8  4.040821e+10        0.737384               5.09              NaN
# 9  2.336536e+10        1.981639              14.90              NaN
#
#    ConfirmedCases_2021  ConfirmedDeaths_2021  CasesPer1k_2021
# 0            5654408.0              117169.0       124.574044  \
# 1             425496.0                2253.0        16.336167
# 2            1270811.0               16815.0       142.312589
# 3             616947.0                8358.0        59.726069
# 4             699110.0                5578.0        73.206017
# 5            2105343.0               28331.0       180.860842
# 6              32840.0                 602.0        81.560275
# 7               2660.0                   3.0         3.410409
# 8             599753.0               19680.0        49.366588
# 9             291313.0               13442.0        89.743981
#
#    DeathsPer1k_2021  GDP_change_pct
# 0          2.581387        8.815706
# 1          0.086500       11.523940
# 2          1.883039        8.039929
# 3          0.809130       13.384626
# 4          0.584090        5.893113
# 5          2.433793       10.875316
# 6          1.495106        3.103662
# 7          0.003846        0.153645
# 8          1.619891       -1.191125
# 9          4.141039       15.655910
#
# [10 rows x 24 columns]

# %%
print(growth_merged_df.columns)
# Out:
# Index(['Unnamed: 0_2019', 'country', 'year_2019', 'population_2019',
#        'GDP_2019', 'inflation_2019', 'unemployment_2019', 'GDP_change_2019',
#        'ConfirmedCases_2019', 'ConfirmedDeaths_2019', 'CasesPer1k_2019',
#        'DeathsPer1k_2019', 'Unnamed: 0_2021', 'year_2021', 'population_2021',
#        'GDP_2021', 'inflation_2021', 'unemployment_2021', 'GDP_change_2021',
#        'ConfirmedCases_2021', 'ConfirmedDeaths_2021', 'CasesPer1k_2021',
#        'DeathsPer1k_2021', 'GDP_change_pct'],
#       dtype='object')

# %%
growth_merged_df = growth_merged_df.drop(['Unnamed: 0_2019','ConfirmedCases_2019','GDP_change_2021', 'ConfirmedDeaths_2019', 'CasesPer1k_2019','DeathsPer1k_2019', 'Unnamed: 0_2021'], axis=1)

# %%
# Sort the dataframe by GDP_change_pct in descending order and select top 15 rows
top_gdp_df = growth_merged_df.sort_values(by='GDP_change_pct', ascending=False).head(20)

# Sort the dataframe by GDP_change_pct in ascending order and select top 15 rows
bottom_gdp_df = growth_merged_df.sort_values(by='GDP_change_pct', ascending=True).head(20)

# %%
top_gdp_df
# Out:
#                    country  year_2019  population_2019      GDP_2019
# 81                 Ukraine       2019     4.438620e+07  1.538830e+11  \
# 34                 Ireland       2019     4.934340e+06  3.993217e+11
# 15                   China       2019     1.407745e+09  1.427994e+13
# 44              Luxembourg       2019     6.200010e+05  6.982564e+10
# 70                  Serbia       2019     6.945235e+06  5.151422e+10
# 12                Bulgaria       2019     6.975761e+06  6.891588e+10
# 35                  Israel       2019     9.054000e+06  4.024705e+11
# 43               Lithuania       2019     2.794137e+06  5.475151e+10
# 25                 Estonia       2019     1.326898e+06  3.108190e+10
# 53                  Norway       2019     5.347896e+06  4.049414e+11
# 76                  Sweden       2019     1.027889e+07  5.338795e+11
# 52             New Zealand       2019     4.979200e+06  2.134346e+11
# 42                  Latvia       2019     1.913822e+06  3.434396e+10
# 9   Bosnia and Herzegovina       2019     3.360711e+06  2.020248e+10
# 21                 Denmark       2019     5.814422e+06  3.464987e+11
# 49                 Moldova       2019     2.664224e+06  1.197135e+10
# 13                  Canada       2019     3.760123e+07  1.742015e+12
# 60                  Poland       2019     3.796548e+07  5.960546e+11
# 14                   Chile       2019     1.903948e+07  2.785847e+11
# 73                Slovenia       2019     2.088385e+06  5.433159e+10
#
#     inflation_2019  unemployment_2019  GDP_change_2019  year_2021
# 81        7.886717               8.19    -2.734879e+09       2021  \
# 34        0.939044               4.95    -2.653058e+10       2021
# 15        2.899234               5.15    -4.077364e+11       2021
# 44        1.743321               5.59    -4.166949e+09       2021
# 70        1.849230              10.39    -1.842258e+09       2021
# 12        3.103729               4.23    -1.324400e+09       2021
# 35        0.844129               3.80    -1.079716e+10       2021
# 43        2.334509               6.26    -2.095113e+09       2021
# 25        2.277259               4.45    -2.884937e+08       2021
# 53        2.167730               3.69     4.274305e+10       2021
# 76        1.784151               6.83    -1.317465e+10       2021
# 52        1.619632               4.11     1.700039e+09       2021
# 42        2.811409               6.31    -2.577793e+08       2021
# 9         0.562782              15.69     2.520084e+08       2021
# 21        0.758132               5.02    -8.723712e+09       2021
# 49        4.837784               1.50     1.116145e+08       2021
# 13        1.949269               5.66     9.659164e+10       2021
# 60        2.227479               3.28    -3.394597e+09       2021
# 14        2.557545               7.27     2.585754e+10       2021
# 73        1.630523               4.45     6.247884e+08       2021
#
#     population_2021      GDP_2021  inflation_2021  unemployment_2021
# 81     4.379286e+07  2.000855e+11        9.363139               9.83  \
# 34     5.033165e+06  5.041826e+11        2.358143               6.19
# 15     1.412360e+09  1.773406e+13        0.981015               5.11
# 44     6.400640e+05  8.550624e+10        2.526920               5.25
# 70     6.834326e+06  6.308205e+10        4.085103              10.06
# 12     6.877743e+06  8.405631e+10        3.297744               5.27
# 35     9.364000e+06  4.885265e+11        1.492288               4.96
# 43     2.800839e+06  6.644526e+10        4.683544               7.11
# 25     1.330932e+06  3.719117e+10        4.653167               6.18
# 53     5.408320e+06  4.821749e+11        3.483881               4.37
# 76     1.041581e+07  6.356638e+11        2.163197               8.72
# 52     5.122600e+06  2.498857e+11        3.941121               3.78
# 42     1.884490e+06  3.985350e+10        3.275829               7.51
# 9      3.270943e+06  2.336536e+10        1.981639              14.90
# 21     5.856733e+06  3.983033e+11        1.853045               5.06
# 49     2.615199e+06  1.367922e+10        5.106411               0.79
# 13     3.824611e+07  1.988336e+12        3.395193               7.46
# 60     3.774712e+07  6.794448e+11        5.055027               3.36
# 14     1.949318e+07  3.170585e+11        4.524568               9.28
# 73     2.108079e+06  6.174859e+10        1.917065               4.74
#
#     ConfirmedCases_2021  ConfirmedDeaths_2021  CasesPer1k_2021
# 81            3847226.0              102088.0        88.780355  \
# 34             788559.0                5912.0       157.526297
# 15             115168.0                4890.0         0.080767
# 44             103766.0                 915.0       161.146847
# 70            1299339.0               12714.0       178.933102
# 12             747108.0               30955.0       109.328276
# 35            1383932.0                8243.0       154.271897
# 43             524427.0                7397.0       189.414910
# 25             241408.0                1932.0       181.837903
# 53             394259.0                1305.0        72.817837
# 76            1314784.0               15310.0       125.007167
# 52              14118.0                  48.0         2.734094
# 42             276674.0                4570.0       148.671290
# 9              291313.0               13442.0        89.743981
# 21             802397.0                3267.0       136.741674
# 49             376155.0               10275.0       123.396547
# 13            2223735.0               30320.0        58.074846
# 60            4108215.0               97054.0       107.441717
# 14            1806494.0               39115.0        92.203682
# 73             464048.0                5589.0       218.912354
#
#     DeathsPer1k_2021  GDP_change_pct
# 81          2.355830       30.024474
# 34          1.181009       26.259755
# 15          0.003429       24.188657
# 44          1.420980       22.456796
# 70          1.750856       22.455595
# 12          4.529809       21.969448
# 35          0.918877       21.381947
# 43          2.671682       21.357852
# 25          1.455258       19.655375
# 53          0.241028       19.072759
# 76          1.455646       19.065026
# 52          0.009296       17.078356
# 42          2.455698       16.042240
# 9           4.141039       15.655910
# 21          0.556751       14.950858
# 49          3.370684       14.266370
# 13          0.791834       14.140021
# 60          2.538243       13.990370
# 14          1.996435       13.810439
# 73          2.636583       13.651355

# %%
bottom_gdp_df
# Out:
#                  country  year_2019  population_2019      GDP_2019
# 47             Mauritius       2019        1265711.0  1.443635e+10  \
# 67           Saint Lucia       2019         178583.0  2.094202e+09
# 10                Brazil       2019      211782878.0  1.873274e+12
# 37               Jamaica       2019        2813773.0  1.583077e+10
# 78              Thailand       2019       71307763.0  5.440811e+11
# 56                Panama       2019        4232532.0  6.698440e+10
# 86                Zambia       2019       18380477.0  2.330867e+10
# 41            Kyrgyzstan       2019        6456200.0  8.871026e+09
# 38                 Japan       2019      126633000.0  5.123318e+12
# 84               Uruguay       2019        3428409.0  6.123115e+10
# 16              Colombia       2019       50187406.0  3.231095e+11
# 58                  Peru       2019       32824861.0  2.283235e+11
# 23               Ecuador       2019       17343740.0  1.081080e+11
# 8                Bolivia       2019       11777315.0  4.089532e+10
# 82  United Arab Emirates       2019        9211657.0  4.179897e+11
# 17            Costa Rica       2019        5084532.0  6.441767e+10
# 7                 Bhutan       2019         767459.0  2.535657e+09
# 48                Mexico       2019      125085311.0  1.269012e+12
# 62           Puerto Rico       2019        3193694.0  1.051264e+11
# 39                Jordan       2019       10698683.0  4.499399e+10
#
#     inflation_2019  unemployment_2019  GDP_change_2019  year_2021
# 47        0.405655           6.330000     3.035303e+09       2021  \
# 67        0.539088          15.320000     5.781860e+08       2021
# 10        3.732976          11.940000     4.247145e+11       2021
# 37        3.905100           4.990000     2.018344e+09       2021
# 78        0.706729           0.720000     4.439930e+10       2021
# 56       -0.355084           6.410000     1.300740e+10       2021
# 86        9.150316           5.540000     5.198036e+09       2021
# 41        1.133623           4.250000     1.090152e+09       2021
# 38        0.468776           2.350000     8.321040e+10       2021
# 84        7.881989           8.730000     7.670395e+09       2021
# 16        3.523019          10.280000     5.280956e+10       2021
# 58        2.252122           3.380000     2.661844e+10       2021
# 23        0.266013           3.810000     8.816885e+09       2021
# 8         1.839545           3.680000     4.265479e+09       2021
# 82       -1.931081           2.330000     6.851671e+10       2021
# 17        2.096046          10.810000     2.259668e+09       2021
# 7         2.725821           2.720000     2.104726e+08       2021
# 48        3.635961           3.480000     1.784964e+11       2021
# 62             NaN           8.300000     2.106100e+09       2021
# 39        0.761514          16.799999     8.116941e+08       2021
#
#     population_2021      GDP_2021  inflation_2021  unemployment_2021
# 47        1266060.0  1.152904e+10        4.028529               8.20  \
# 67         179651.0  1.691275e+09        2.410703              19.52
# 10      214326223.0  1.608981e+12        8.301660              13.16
# 37        2827695.0  1.465759e+10        5.862782               8.35
# 78       71601103.0  5.059470e+11        1.230395               1.21
# 56        4351267.0  6.360510e+10        1.630703              10.29
# 86       19473125.0  2.214763e+10       22.021234               5.20
# 41        6691800.0  8.543424e+09       11.905040               4.10
# 38      125681593.0  4.940878e+12       -0.233353               2.80
# 84        3426260.0  5.931948e+10        7.747914               9.29
# 16       51516562.0  3.144641e+11        3.495058              13.90
# 58       33715471.0  2.232495e+11        4.271664               5.10
# 23       17797737.0  1.061659e+11        0.133251               4.50
# 8        12079472.0  4.040821e+10        0.737384               5.09
# 82        9365145.0  4.150216e+11             NaN               3.11
# 17        5153957.0  6.428244e+10        1.726478              15.14
# 7          777486.0  2.539553e+09        7.346839               4.80
# 48      126705138.0  1.272839e+12        5.689208               4.09
# 62        3263584.0  1.065257e+11             NaN               7.90
# 39       11148278.0  4.574427e+10        1.346094              19.84
#
#     ConfirmedCases_2021  ConfirmedDeaths_2021  CasesPer1k_2021
# 47              68480.0                 786.0        52.712037  \
# 67                  NaN                   NaN              NaN
# 10           22291839.0              619334.0       103.767543
# 37              93920.0                2473.0        33.199116
# 78            2223435.0               21698.0        31.036114
# 56             495920.0                7428.0       113.242308
# 86             254274.0                3734.0        12.877412
# 41                  NaN                   NaN              NaN
# 38            1733307.0               18392.0        13.946979
# 84             413383.0                6170.0       120.779801
# 16            5157440.0              129942.0        99.585959
# 58            2296831.0              202690.0        67.729727
# 23             549418.0               33681.0        30.684407
# 8              599753.0               19680.0        49.366588
# 82             761937.0                2164.0        81.029017
# 17             570556.0                7353.0       110.421723
# 7                2660.0                   3.0         3.410409
# 48            3979723.0              299428.0        31.330448
# 62             272724.0                3305.0        83.937185
# 39            1063405.0               12653.0        94.472908
#
#     DeathsPer1k_2021  GDP_change_pct
# 47          0.605018      -20.138819
# 67               NaN      -19.240103
# 10          2.882973      -14.108610
# 37          0.874163       -7.410769
# 78          0.302874       -7.008886
# 56          1.696168       -5.044906
# 86          0.189104       -4.981121
# 41               NaN       -3.692950
# 38          0.147990       -3.560981
# 84          1.802714       -3.122047
# 16          2.509074       -2.675688
# 58          5.976991       -2.222284
# 23          1.881048       -1.796484
# 8           1.619891       -1.191125
# 82          0.230133       -0.710097
# 17          1.423052       -0.209929
# 7           0.003846        0.153645
# 48          2.357253        0.301618
# 62          1.017191        1.331064
# 39          1.124093        1.667510
